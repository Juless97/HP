# %%
import pandas as pd
import numpy as np
import os
import glob
from typing import Tuple

# %%
row_data_folder = (glob.glob('./HP_data/**/*.csv', recursive=True))

# %%
print(row_data_folder)
# Out:
# ['./HP_data/Respeck_s2251802_Climbing stairs_28-10-2021_22-44-32.csv', './HP_data/Respeck_s1788488_Movement_28-10-2021_21-30-49.csv', './HP_data/Respeck_s2251802_Running_28-10-2021_22-41-36.csv', './HP_data/Respeck_s2101848_Descending stairs_28-10-2021_23-04-27.csv', './HP_data/Respeck_s1724067_Running_28-10-2021_21-38-31.csv', './HP_data/Respeck_s1820742_Movement_28-10-2021_17-25-17.csv', './HP_data/Respeck_s1724067_Climbing stairs_28-10-2021_21-41-16.csv', './HP_data/Respeck_s2056220_Walking at normal speed_28-10-2021_21-15-45.csv', './HP_data/Respeck_s1788488_Climbing stairs_28-10-2021_21-32-41.csv', './HP_data/Respeck_s1820742_Descending stairs_28-10-2021_17-35-43.csv', './HP_data/Respeck_s2048692_Climbing stairs_28-10-2021_22-55-07.csv', './HP_data/Respeck_s2048692_Descending stairs_28-10-2021_22-54-39.csv', './HP_data/Respeck_s2106215_Descending stairs_28-10-2021_23-32-19.csv', './HP_data/Respeck_s1820742_Descending stairs_28-10-2021_17-36-05.csv', './HP_data/Respeck_s1724067_C
# ...

# %%
for row_data in row_data_folder:
    filename_respeck=row_data
    try:
        # %run ./data_clean.ipynb
    except:
        pass
# Out:
# Sensor type: Respeck
# Activity type: Climbing stairs
# Activity code: 12
# Subject id: s2251802
# Notes:
# Sensor type: Respeck
# Activity type: Climbing stairs
# Activity code: 12
# Subject id: s2251802
# Notes:
# Sensor type: Respeck
# Activity type: Climbing stairs
# Activity code: 12
# Subject id: s2251802
# Notes:
#          timestamp   accel_x   accel_y   accel_z    gyro_x     gyro_y  \
# 0    1635457465399  0.082520 -0.932922  0.011169  2.656250  29.156250
# 1    1635457465437  0.101074 -1.037170 -0.021790  8.015625  27.046875
# 2    1635457465476  0.062744 -1.065002 -0.004211  2.984375  14.921875
# 3    1635457465512  0.018066 -1.006165  0.064880  5.796875  14.609375
# 4    1635457465550  0.033203 -1.010071  0.051697  4.453125  12.671875
# ..             ...       ...       ...       ...       ...        ...
# 172  1635457472150  0.149902 -0.954163 -0.041809 -0.609375   4.062500
# 173  1635457472188  0.289795 -0.803284  0.057800 -2.281250   6.421875
# ...
